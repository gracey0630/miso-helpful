# %% [markdown]
# **Citation**
#
# Data for this project comes from this source: N. Sakib, G. Shahariar, M. M. Kabir, M. K. Hasan, and H. Mahmud, “Assorted, archetypal and annotated two million (3a2m) cooking recipes dataset based on active learning.” (https://www.kaggle.com/datasets/nazmussakibrupol/3a2m-cooking-recipe-dataset)

# %%
import pandas as pd
from pathlib import Path
import json

# %%
current_dir = Path.cwd()  # .../src/data_processing
project_root = current_dir.parent.parent  # Go up 2 levels to main dir

output_parent =  project_root / "data" / "processed"
raw_data_folder = project_root / "data" / "raw"

# %%
df = pd.read_csv(raw_data_folder / "3A2M.csv")
df.head()
# Out:
#    Unnamed: 0                               title  \
# 0           0                Reeses Cups(Candy)
# 1           1                 Rhubarb Coffee Cake
# 2           2                Quick Barbecue Wings
# 3           3              Chocolate Frango Mints
# 4           4  Corral Barbecued Beef Steak Strips
#
#                                           directions  \
# 0  ["Combine first four ingredients and press in ...
# 1  ["Cream sugar and butter.", "Add egg and beat ...
# 2  ["Clean wings.", "Flour and fry until done.", ...
# 3  ["Mix ingredients together for 5 minutes.", "S...
# 4  ["Brown strips in cooking oil.", "Pour off dri...
#
#                                                  NER   genre  label
# 0  ["peanut butter", "graham cracker crumbs", "bu...  drinks      2
# 1  ["sugar", "butter", "egg", "buttermilk", "flou...  drinks      2
# 2             ["chicken", "flour", "barbecue sauce"]  nonveg      3
# 3  ["cake mix", "chocolate fudge pudding", "sour ...  drinks      2
# 4  ["long", "cooking oil", "tomato sauce", "water...  drinks      2

# %%
df.shape
# Out:
# (2231143, 6)

# %% [markdown]
# As seen the dataset has over 2 million rows, which is too large for the purpose of our project, so we will use stratified random sampling based on the genre to select 4500 random rows to use as data instead. This is 500 rows from each of the 9 genres.

# %%
df.drop(['Unnamed: 0', 'label'], axis=1, inplace=True)
df.head()
# Out:
#                                 title  \
# 0                Reeses Cups(Candy)
# 1                 Rhubarb Coffee Cake
# 2                Quick Barbecue Wings
# 3              Chocolate Frango Mints
# 4  Corral Barbecued Beef Steak Strips
#
#                                           directions  \
# 0  ["Combine first four ingredients and press in ...
# 1  ["Cream sugar and butter.", "Add egg and beat ...
# 2  ["Clean wings.", "Flour and fry until done.", ...
# 3  ["Mix ingredients together for 5 minutes.", "S...
# 4  ["Brown strips in cooking oil.", "Pour off dri...
#
#                                                  NER   genre
# 0  ["peanut butter", "graham cracker crumbs", "bu...  drinks
# 1  ["sugar", "butter", "egg", "buttermilk", "flou...  drinks
# 2             ["chicken", "flour", "barbecue sauce"]  nonveg
# 3  ["cake mix", "chocolate fudge pudding", "sour ...  drinks
# 4  ["long", "cooking oil", "tomato sauce", "water...  drinks

# %%
stratified_sampled_df = (
    df
    .groupby("genre", group_keys = False)
    .apply(lambda x: x.sample(n = 500, random_state = 36))
)

stratified_sampled_df.head()
# Out:
# /var/folders/k1/gcdz_f255j11p1gkqhhj0p4h0000gn/T/ipykernel_4454/754604607.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n = 500, random_state = 36))
#                               title  \
# 2108573        Breakfast Speciality
# 2003055               Hello Dollies
# 2059741  Linguine A La Margarita D.
# 2178316           Stuffed Mirlitons
# 2215443               Noodle Squeal
#
#                                                 directions  \
# 2108573  Butter one or both sides of bread. Cut in cube...
# 2003055  Combine ingredients. Bake for 30 minutes at 35...
# 2059741  Put the vegetable oil in saucepan or melt the ...
# 2178316  Peel mirlitons and boil until tender. Save som...
# 2215443  Cut and cook sausage pepper and onion together...
#
#                                                        NER   genre
# 2108573  ["eggs", "bread", "pork sausage", "Cheddar che...  Fusion
# 2003055  ["oleo", "graham crackers", "milk", "chocolate...  Fusion
# 2059741  ["linguine", "vegetable oil", "garlic", "lime ...  Fusion
# 2178316  ["mirlitons", "onions", "celery", "bell pepper...  Fusion
# 2215443  ["noodles", "onion", "green pepper", "tomato s...  Fusion

# %%
stratified_sampled_df.shape
# Out:
# (5000, 4)

# %%
stratified_sampled_df.rename(columns={'title': 'recipe_name', 'NER': 'ingredients', 'genre': 'recipe_category'}, inplace=True)
stratified_sampled_df.head()
# Out:
#                         recipe_name  \
# 2108573        Breakfast Speciality
# 2003055               Hello Dollies
# 2059741  Linguine A La Margarita D.
# 2178316           Stuffed Mirlitons
# 2215443               Noodle Squeal
#
#                                                 directions  \
# 2108573  Butter one or both sides of bread. Cut in cube...
# 2003055  Combine ingredients. Bake for 30 minutes at 35...
# 2059741  Put the vegetable oil in saucepan or melt the ...
# 2178316  Peel mirlitons and boil until tender. Save som...
# 2215443  Cut and cook sausage pepper and onion together...
#
#                                                ingredients recipe_category
# 2108573  ["eggs", "bread", "pork sausage", "Cheddar che...          Fusion
# 2003055  ["oleo", "graham crackers", "milk", "chocolate...          Fusion
# 2059741  ["linguine", "vegetable oil", "garlic", "lime ...          Fusion
# 2178316  ["mirlitons", "onions", "celery", "bell pepper...          Fusion
# 2215443  ["noodles", "onion", "green pepper", "tomato s...          Fusion

# %%
#convert to json
recipe_list = []

for index, row in stratified_sampled_df.iterrows():
    recipe_list.append(row.to_dict())

print(recipe_list[0:5])
# Out:
# [{'recipe_name': 'Breakfast Speciality', 'directions': 'Butter one or both sides of bread. Cut in cubes and lay in pan (9 x 13-inch). Sprinkle cooked sausage over bread cubes. Grate cheese over sausage. In a bowl combine eggs half and half salt pepper and dry mustard. Mix at slow speed until well blended. Pour over other ingredients and refrigerate overnight. Bake at 350\\u00b0 about 40 to 45 minutes in the morning and do not drain.', 'ingredients': '["eggs", "bread", "pork sausage", "Cheddar cheese", "dry mustard", "salt"]', 'recipe_category': 'Fusion'}, {'recipe_name': 'Hello Dollies', 'directions': 'Combine ingredients. Bake for 30 minutes at 350\\u00b0 in a 9 x 13-inch pan.', 'ingredients': '["oleo", "graham crackers", "milk", "chocolate chips", "coconut", "nuts"]', 'recipe_category': 'Fusion'}, {'recipe_name': 'Linguine A La Margarita D.', 'directions': "Put the vegetable oil in saucepan or melt the butter. Add the squeezed garlic lime juice lemon juice vermouth salt and pepper cook with medium heat for 20 minutes. Add fresh cleaned shrimp and cook for 6 minutes don't overcook. Make sure that the linguine is prepared so that it is finished to your liking at about the same time that the shrimp sauce is finished. Serve with Chilean wine and a nice smile.", 'ingredients': '["linguine", "vegetable oil", "garlic", "lime juice", "lemon juice", "sweet vermouth", "salt", "ground pepper", "shrimp"]', 'recipe_category': 'Fusion'}, {'recipe_name': 'Stuffed Mirlitons', 'directions': 'Peel mirlitons and boil until tender. Save some of the water. Put vegetables in pot and cook to clear in oil. Add ham and saute. Put cooked mirlitons in pot and cook for about 1 hour slowly. Put shrimp in pot and cook until shrimp turn pink. Add some of the mirliton water to pot and then cook for 1/2 hour. Add enough bread crumbs to make stuffing stiff. Add salt and pepper to taste. Add 1/2 stick butter and stir well. Place in casserole dish. Sprinkle with bread crumbs and dot with butter. Cook in oven at 250\\u00b0 to 300\\u00b0 until hot.', 'ingredients': '["mirlitons", "onions", "celery", "bell pepper", "green onions", "garlic", "parsley", "thyme", "bay leaf", "shrimp", "ham", "Italian bread crumbs", "salt", "oil"]', 'recipe_category': 'Fusion'}, {'recipe_name': 'Noodle Squeal', 'directions': 'Cut and cook sausage pepper and onion together until brown. Cook noodles and drain. Mix noodles and sausage mixture and tomato soup together. Put a layer of noodle mixture layer of cheese alternately until used up ending up with cheese on top. Bake at 350\\u00b0 for 20 to 25 minutes.', 'ingredients': '["noodles", "onion", "green pepper", "tomato soup", "sausage"]', 'recipe_category': 'Fusion'}]

# %%
with open(output_parent/"3a2m_recipe_data.json", "w", encoding='utf-8') as f:
    json.dump(recipe_list, f, indent=2, ensure_ascii=False)
